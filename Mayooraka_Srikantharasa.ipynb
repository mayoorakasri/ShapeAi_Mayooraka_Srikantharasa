# %%
from keras.datasets import mnist
data=mnist.load_data()

# %%
((x_train,y_train),(x_test,y_test))=data

# %%
x_train=x_train.reshape((x_train.shape[0],28*28)).astype('float32')

# %%
 x_test=x_test.reshape((x_test.shape[0],28*28)).astype('float32')

# %%
x_train=x_train/255
x_test=x_test/255

# %%
 from keras.utils import np_utils
 
print(y_test.shape)
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)
# Out:
# (10000,)

# %%
num_classes=y_test.shape[1]
print(y_test.shape)
# Out:
# (10000, 10)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
 model =Sequential()
model.add(Dense(32,input_dim=28*28,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
 model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
 model.summary()
model.fit(x_train,y_train,epochs=10,batch_size=100)
scores=model.evaluate(x_test,y_test)
print(scores)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7282 - accuracy: 0.7834
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2054 - accuracy: 0.9402
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1629 - accuracy: 0.9505
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1319 - accuracy: 0.9603
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1145 - accuracy: 0.9660
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0998 - accuracy: 0.9705
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0920 - accuracy: 0.9728
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0795 - accuracy: 0.9751
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0708 - accuracy: 0.9783
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0670 - accuracy: 0.9798
# 313/313 [==============================] - 0s 963us/step - loss: 0.1036 - accuracy: 0.9684
# [0.10360092669725418, 0.9684000015258789]
